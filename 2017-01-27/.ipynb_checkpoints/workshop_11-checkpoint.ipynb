# %% [markdown]
# # Workshop n°11: Suburban neighborhood design

# %% [markdown]
# # Roberto Nunziato, matricola 438778

# %% [markdown]
# # Descrizione

# %% [markdown]
# L'obiettivo di questo workshop è quello di costruire un modello di quartiere abitativo. L'immagine da cui si è preso spunto per la riproduzione è la seguente, presa dal web:

# %% [markdown]
# ![text-alt](planimetriaVicinato.jpg)

# %% [markdown]
# Per la sua realizzazione si è proceduto nel seguente modo:
#
# 1) Ho ridefinito su carta le coordinate principali che rappresentano le strade del quartiere
# 2) Costruito il sistema di strade, ho replicato lungo le stesse le case costruite nel workshop precendente
# 3) Ho definito anche un semplice modello di albero, al fine di abbellire il modello finale

# %% [markdown]
# # Librerie usate

# %%
from pyplasm import *
from casa import *

# %% [markdown]
# # Codice per la realizzazione del modello finale

# %%
"""
    getBezierCurve è un funzione che, data una lista di punti, ritorna una curva di Bezier
    @input: points, lista di punti
    @output: oggetto HPC che rappresenta la curva
"""
def getBezierCurve(points):
    curve = MAP(BEZIER(S1)(points))(INTERVALS(1)(100))
    return OFFSET([3,3])(curve)

"""
    costruisciStrade è una funzione che costruisce il sistema di strade del quartiere, sulla 
    base di una serie di punti definiti su carta
    @output : HPC della strada
"""
def costruisciStrade():
    points1 = [[110,60],[90,90],[78,120],[72,130],[71,140],[72,150],[73,160],[78,170],[80,180],[88,190],
               [92,200],[102,210],[150,240],[220,270],[240,278],[250,279],[260,280],[270,280],[280,279],[290,278],
               [300,275],[310,270],[320,262],[330,250],[335,240],[340,230],[342,220],[346,210],[350,200],[350,190],
               [349,180],[342,160],[330,130],[318,110],[301,91],[300,90],[290,90],[270,90],[240,88],[190,80],
               [142,70],[110,60]]
    strada1 = getBezierCurve(points1)
    
    points2 = [[80,120],[90,121],[100,125],[110,128],[120,130],[130,132],[140,138],[150,140],[160,142],[178,150],
               [185,155],[190,160],[195,165],[200,170],[201,180],[200,190],[198,198],[195,205],[190,210],[186,218],
               [180,222],[170,230],[160,235],[150,227.1]]
    strada2 = getBezierCurve(points2)

    points3 = [[80,165],[80,167],[85,162],[90,160],[95,158],[100,158],[105,158],[110,159],[115,160],[120,162],
               [125,165],[130,170],[135,173],[140,176],[145,178],[150,180],[155,181],[160,182],[170,180],[185,180],
               [195,180]]
    strada3 = getBezierCurve(points3)

    points4 = [[220,260],[228,250],[230,238],[235,220],[240,210],[250,195],[255,190],[260,185],[267,180],[280,170],
               [290,168],[300,162],[310,160],[320,158],[330,157],[334,160]]
    strada4 = getBezierCurve(points4)

    points5 = [[244,210],[250,218],[260,225],[265,227],[270,228],[275,229],[280,229],[285,227],[290,226],[295,225],
               [300,221],[305,218],[310,213],[312,217],[315,200],[315,195],[314,190],[312,184],[308,173],[310,162]]
    strada5 = getBezierCurve(points5)

    points6 = [[300,265],[315,280],[325,290],[338,300],[350,308],[360,310],[365,312],[372,311],[380,310],[386,308],
               [390,305],[392,300],[397,295],[400,290],[402,285],[403,280],[403,275],[400,270],[398,263],[390,260],
               [380,250],[360,240],[350,235],[335,230]]
    strada6 = getBezierCurve(points6)

    points7 = [[325,288],[373,248]]
    strada7 = getBezierCurve(points7)

    points8 = [[395,265],[393,250],[390,240],[389,235],[388,230],[387,225],[386,220],[385,210],[384,200],[385,190],
               [385,180],[385,170],[384,160],[382,150],[380,140],[378,130],[373,120],[368,102],[360,90],[300,90],
               [280,95]]
    strada8 = getBezierCurve(points8)

    points9 = [[383,170],[370,165],[360,161],[350,160],[337,160]]
    strada9 = getBezierCurve(points9)

    points10 = [[120,210],[105,215],[90,218],[85,219],[80,220],[70,220],[60,219],[55,218],[50,215],[45,213],
                [40,211],[30,210]]
    strada10 = getBezierCurve(points10)

    points11 = [[75,150],[65,148],[60,145],[55,142],[50,140],[45,138],[40,135],[35,132],[30,131],[20,130]]
    strada11 = getBezierCurve(points11)

    points12 = [[91,90],[85,85],[80,80],[75,75],[70,70],[65,68],[60,64],[52,60],[48,58],[40,55],
                [30,50]]
    strada12 = getBezierCurve(points12)
    
    #Assemblo tutte le strade
    strade = STRUCT([strada1,strada2,strada3,
                     strada4,strada5,strada6,
                     strada7,strada8,strada9,
                     strada10,strada11,strada12])
    strade = COLOR([128/255.,128/255.,128/255.,1])(strade)
    return strade

"""
    disegnaAlbero è una funzione che definisce un modello semplificato di albero
    @outpu : HPC dell'albero
"""
def disegnaAlbero():
    tronco = CYLINDER([.45,7])(100)
    tronco = COLOR([121/255.,68/255.,59/255.,1])(tronco)
    pianta = CONE([2,10])(10)
    pianta = COLOR([0,168/255.,107/255.,1])(pianta)
    albero = STRUCT([tronco,T(3)(7)(pianta)])
    return albero

"""
    disegnaLago è una funzione che, dati una serie di punti definiti su carta, costruisce un
    modellino di lago, da piazzare poi nella parte alta del modello finale
    @output : HPC del laghetto
"""
def disegnaLago():
    points = [[30,261],[40,260],[46,262],[55,265],[60,267],[67,268],[75,265],[82,262],[90,260],[100,261],
              [110,265],[120,270],[125,275],[132,280],[140,285],[150,290],[160,290],[170,293],[180,298],[185,295],
              [186,313],[184,320],[187,326],[168,328],[158,325],[150,323],[140,327],[138,330],[130,335],[120,334],
              [110,332],[100,330],[90,327],[82,322],[75,318],[70,310],[63,305],[55,300],[47,296],[40,290],[36,283],
              [33,277],[30,270],[30,261]]
    lago = MAP(BEZIER(S1)(points))(INTERVALS(1)(100))
    lago = OFFSET([35,48])(lago)
    lago = COLOR([62/255.,214/255.,239/255.,1])(lago)
    lago = S([1,2,3])([.4,.4,.4])(lago)
    lago = T([1,2,3])([70,150])(lago)
    return lago

"""
    costruisciQuartiere è una funzione che assembla le varie componenti (strade,lago,case ed alberi)
    per poi andare a costruire il modello finale di quartiere. Il modello poggerà su una base simil legno,
    al fine di emulare una sorta di "plastico" dell'intero progetto
    @output : HPC del quartiere
"""
def costruisciQuartiere():
    strade = costruisciStrade()
    lago = disegnaLago()
    #Costruisco una casa, presa dal workshop precedente
    casa = disegnaCasa()
    casa = T([1,2])([0,0])(casa)
    casa = R([1,2])(-PI/2)(casa)
    #Inizio ad assemblare il quartiere introducendo lungo le strade diverse repliche della casa
    quartiere = STRUCT([T([1,2])([35,73])(R([1,2])(PI/6)(casa)),T([1,2])([58,85])(R([1,2])(2.25*PI)(casa)),
                   T([1,2])([140,50])(R([1,2])(3.35)(casa)),T([1,2])([180,60])(R([1,2])(3.35)(casa)),               
                   T([1,2])([220,67])(R([1,2])(3.35)(casa)),T([1,2])([260,74])(R([1,2])(3.35)(casa)),               
                   T([1,2])([320,78])(R([1,2])(3.2)(casa)),T([1,2])([360,88])(R([1,2])(3.5)(casa)),               
                   T([1,2])([385,110])(R([1,2])(4)(casa)), T([1,2])([400,150])(R([1,2])(4.5)(casa)),               
                   T([1,2])([405,200])(R([1,2])(4.7)(casa)),T([1,2])([408,235])(R([1,2])(4.6)(casa)),               
                   T([1,2])([418,295])(R([1,2])(4.8)(casa)),T([1,2])([390,325])(R([1,2])(5.7)(casa)),               
                   T([1,2])([340,319])(R([1,2])(6.7)(casa)),T([1,2])([305,295])(R([1,2])(7)(casa)),               
                   T([1,2])([270,290])(R([1,2])(6.2)(casa)),T([1,2])([230,283])(R([1,2])(6.5)(casa)),               
                   T([1,2])([185,265])(R([1,2])(6.7)(casa)),T([1,2])([150,248])(R([1,2])(6.8)(casa)),               
                   T([1,2])([115,226])(R([1,2])(6.9)(casa)),T([1,2])([95,237])(R([1,2])(6)(casa)),               
                   T([1,2])([65,237])(R([1,2])(6.3)(casa)),T([1,2])([35,230])(R([1,2])(6.5)(casa)),               
                   T([1,2])([50,160])(R([1,2])(6.7)(casa)),T([1,2])([20,150])(R([1,2])(6.5)(casa)),               
                   T([1,2])([130,85])(R([1,2])(6.48)(casa)),T([1,2])([175,94])(R([1,2])(6.48)(casa)),               
                   T([1,2])([215,100])(R([1,2])(6.4)(casa)),T([1,2])([258,108])(R([1,2])(6.5)(casa)),               
                   T([1,2])([282,116])(R([1,2])(6.9)(casa)),T([1,2])([300,130])(R([1,2])(7.3)(casa)),               
                   T([1,2])([312,145])(R([1,2])(9.1)(casa)),T([1,2])([276,158])(R([1,2])(8.9)(casa)),               
                   T([1,2])([234,195])(R([1,2])(8.4)(casa)),T([1,2])([215,195])(R([1,2])(11)(casa)),               
                   T([1,2])([200,230])(R([1,2])(11.6)(casa)),T([1,2])([245,256])(R([1,2])(11.4)(casa)),               
                   T([1,2])([275,246])(R([1,2])(12.4)(casa)),T([1,2])([330,210])(R([1,2])(11)(casa)),               
                   T([1,2])([360,210])(R([1,2])(11)(casa)),T([1,2])([355,180])(R([1,2])(12.9)(casa)),               
                   T([1,2])([360,287])(R([1,2])(11.9)(casa)),T([1,2])([160,200])(R([1,2])(12.5)(casa)),               
                   T([1,2])([100,177])(R([1,2])(12.8)(casa)),T([1,2])([100,142])(R([1,2])(12.9)(casa)),               
                   T([1,2])([140,156])(R([1,2])(12.9)(casa)),T([1,2])([145,122])(R([1,2])(3.5)(casa)),               
                   T([1,2])([195,147])(R([1,2])(3.7)(casa)),strade,lago])
    albero = disegnaAlbero()
    #Aggiungo in più punti del quartiere diverse copie di albero
    quartiere = STRUCT([T([1,2])([100,300])(albero),T([1,2])([90,290])(albero),T([1,2])([80,280])(albero),
                        T([1,2])([85,290])(albero),T([1,2])([95,300])(albero),T([1,2])([85,300])(albero),
                        T([1,2])([100,300])(albero),T([1,2])([80,270])(albero),T([1,2])([75,275])(albero),
                        T([1,2])([75,285])(albero),T([1,2])([75,295])(albero),T([1,2])([80,295])(albero),                    
                        T([1,2])([280,210])(albero),T([1,2])([270,215])(albero),T([1,2])([280,220])(albero),
                        T([1,2])([290,215])(albero),T([1,2])([295,205])(albero),T([1,2])([300,200])(albero),
                        T([1,2])([305,195])(albero),T([1,2])([295,190])(albero),T([1,2])([285,200])(albero),
                        T([1,2])([300,180])(albero),T([1,2])([290,180])(albero),T([1,2])([280,180])(albero),
                        T([1,2])([280,190])(albero),T([1,2])([270,190])(albero),T([1,2])([270,200])(albero),
                        T([1,2])([263,193])(albero),T([1,2])([265,205])(albero),T([1,2])([260,210])(albero),
                        T([1,2])([255,205])(albero),T([1,2])([140,100])(albero),T([1,2])([155,100])(albero),
                        T([1,2])([160,100])(albero),T([1,2])([170,100])(albero),T([1,2])([200,110])(albero),
                        T([1,2])([190,120])(albero),T([1,2])([175,115])(albero),T([1,2])([160,110])(albero),
                        T([1,2])([180,120])(albero),T([1,2])([205,115])(albero),T([1,2])([220,110])(albero),
                        T([1,2])([240,110])(albero),T([1,2])([240,120])(albero),T([1,2])([230,130])(albero),
                        T([1,2])([215,135])(albero),T([1,2])([215,145])(albero),T([1,2])([200,140])(albero),
                        T([1,2])([220,160])(albero),T([1,2])([230,155])(albero),T([1,2])([230,140])(albero),
                        T([1,2])([240,140])(albero),T([1,2])([240,150])(albero),T([1,2])([250,160])(albero),
                        T([1,2])([250,170])(albero),T([1,2])([235,165])(albero),T([1,2])([230,175])(albero),
                        T([1,2])([250,115])(albero),T([1,2])([260,120])(albero),T([1,2])([267,115])(albero),
                        T([1,2])([280,115])(albero),T([1,2])([275,125])(albero),T([1,2])([260,130])(albero),
                        T([1,2])([250,130])(albero),T([1,2])([255,145])(albero),T([1,2])([265,155])(albero),
                        T([1,2])([270,140])(albero),T([1,2])([350,130])(albero),T([1,2])([340,130])(albero),
                        T([1,2])([355,125])(albero),T([1,2])([365,125])(albero),T([1,2])([360,115])(albero),
                        T([1,2])([350,115])(albero),T([1,2])([340,115])(albero),T([1,2])([330,115])(albero),
                        T([1,2])([320,100])(albero),T([1,2])([370,135])(albero),T([1,2])([365,145])(albero),
                        T([1,2])([355,150])(albero),T([1,2])([345,140])(albero),T([1,2])([340,260])(albero),
                        T([1,2])([350,260])(albero),T([1,2])([355,255])(albero),T([1,2])([345,255])(albero),
                        T([1,2])([330,265])(albero),T([1,2])([355,245])(albero),T([1,2])([325,275])(albero),
                        T([1,2])([325,265])(albero),T([1,2])([325,255])(albero),T([1,2])([330,275])(albero),
                        T([1,2])([330,265])(albero),T([1,2])([330,255])(albero),T([1,2])([335,245])(albero),
                        T([1,2])([340,238])(albero),quartiere])
    #Disegno il prato e lo aggiungo al quartiere
    prato = MKPOL([[[15,40],[420,40],[420,330],[15,330]],[[1,2,3,4]],None])
    prato = DIFFERENCE([prato,strade])
    prato = COLOR([0,225/255.,0,1])(prato)
    quartiere = STRUCT([quartiere,prato])
    quartiere = T(3)(2.3)(quartiere)
    #Disegno la base di legno del modello
    base = CUBOID([430,350,2])
    base = COLOR([121/255.,68/255.,59/255.,1])(base)
    return STRUCT([quartiere,base])

VIEW(costruisciQuartiere())
